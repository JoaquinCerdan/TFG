# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaquinCerdan/TFG/blob/development/Extracction_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# !pip install tika
from tika import parser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tika
#   Downloading tika-2.6.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tika) (67.7.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tika) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (3.4)
# Building wheels for collected packages: tika
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32625 sha256=0b2df01e74b8ff5cd02693f889f25c617413adfa8192e5c90fef46f24c3e7440
#   Stored in directory: /root/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built tika
# Installing collected packages: tika
# Successfully installed tika-2.6.0

# %%
document = "/content/contratos-formalizados-2015";



# opening pdf file
parsed_pdf = parser.from_file(document + ".pdf")

# saving content of pdf
# you can also bring text only, by parsed_pdf['text']
# parsed_pdf['content'] returns string
data = parsed_pdf['content']

with open(document + ".txt", 'w') as f:
    f.write(data)

# writing to file
file1 = open(document + ".txt", 'r')
Lines = file1.readlines()
# Out:
# 2023-06-14 14:27:33,661 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar to /tmp/tika-server.jar.
# INFO:tika.tika:Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar to /tmp/tika-server.jar.
# 2023-06-14 14:27:34,095 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar.md5 to /tmp/tika-server.jar.md5.
# INFO:tika.tika:Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar.md5 to /tmp/tika-server.jar.md5.
# 2023-06-14 14:27:34,491 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# WARNING:tika.tika:Failed to see startup log message; retrying...
# 2023-06-14 14:27:39,506 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# WARNING:tika.tika:Failed to see startup log message; retrying...

# %%
# Crea listas de cada página
def extractPages(myList, pages):
  for line in Lines:
    if line.find("de Alicante CONTRATOS FORMALIZADOS") != -1:
      pages +=1
      if pages !=0:
        #writeTxt(myList, pages)
        extractDataFormalizados(myList, pages)
        myList = []
    if line != '\n':
      myList.append(line)
  extractDataFormalizados(myList, pages+1)

# %%
# Extraemos la primera página para poder controlar el formato
def extractPage(myList1, pages1, page1):
  for line in Lines:
    if line.find("de Alicante CONTRATOS FORMALIZADOS") != -1:
      pages1 +=1
      if pages1 == page1:
        writeTxt(myList1,page1)
        break;
      else:
        myList1 = []
    if line != '\n':
      myList1.append(line)

# %%
# Crea un documento txt de la primera página

def writeTxt(data_List, page):
  data_Str = ' '.join(data_List)
  with open(document + "_"+ str(page) + ".txt", 'w') as f:
    f.write(data_Str)

# %%
# Extrae los datos de una página de los contratos formalizados guardada en una lista de Strings


#numExpediente, objContrato, tipoTramitacion, tipoContrato, importeLicitacion = " "
#importeTotalLicitacion, identificadorContratista, razonSocial, importeAdjudicacionSin, importeTotalAdjudicacion = " "
#plazoEjecucion, fechaFormalizacion, lotesContrato, cuentaLotes, descripcionLotes = " "

def extractDataFormalizados(pagina, pages):
  #print("Aqui se extraerían los datos de la página " + str(pages))
  for count, value in enumerate(pagina):
    if "Nº Expediente:" in value:
      numExpediente = value[(value.find("Nº Expediente:")) + 15:]
      #print(numExpediente)
    if "Página:" in value:
      objContrato = pagina[count+1]
      if "Objeto del contrato:" not in pagina[count+2]:
        linea2 = pagina[count+2]
        objContrato += linea2
        objContrato = objContrato.replace('\n', " ")
      #print(str(pages)+ "-" + objContrato)
    if "Tramitación:" in value:
      tipoTramitacion = value[(value.find("Tramitación:")) + 13:]
      #print(tipoTramitacion)

# %%
myList = []
pages = -1

# Ejecutar todo
extractPages(myList, pages)
# Out:
# 8/2015
#
# Anticipada
#
# 2/2015
#
# Ordinaria
#
# 4/2015
#
# Ordinaria
#
# 1/2015
#
# Ordinaria
#
# 1/2015
#
# Ordinaria
#
# 1/2015
#
# Ordinaria
#
# 1/2015
#
# Ordinaria
#
# 7/2015
#
# Anticipada
#
# 13/2015
#
# Ordinaria
#
# 17/2015
#
# Ordinaria
#
# 8/2015
#
# Ordinaria
#
# 19/2015
#
# Ordinaria
#
# 4/2015
#
# Ordinaria
#
# 4/2015
#
# Ordinaria
#
# 1/2015
#
# Ordinaria
#
# 6/2015
#
# Urgente
#
# 1/2015
#
# Ordinaria
#
# 5/2015
#
# Ordinaria
#
# 4/2015
#
# Anticipada
#
# 1/2015
#
# Ordinaria
#
# 2/2015
#
# Ordinaria
#
# 6/2015
#
# Ordinaria
#
# 4/2015
#
# Ordinaria
#
# 5/2015
#
# Ordinaria
#
# 1/2015
#
# Urgente
#
# 8/2015
#
# Ordinaria
#
# 8/2015
#
# Ordinaria
#
# 7/2015
#
# Anticipada
#
# 2/2015
#
# Ordinaria
#
# 11/2015
#
# Ordinaria
#
# 10/2015
#
# Ordinaria
#
# 10/2015
#
# Ordinaria
#
# 10/2015
#
# Urgente
#
# 2/2015
#
# Urgente
#
# 7/2015
#
# Urgente
#
# 4/2015
#
# Urgente
#
# 3/2015
#
# Urgente
#
# 3/2015
#
# Ordinaria
#
# 12/2015
#
# Ordinaria
#
# 13/2015
#
# Ordinaria
#
# 6/2015
#
# Ordinaria
#
# 37/2015
#
# Ordinaria
#
# 14/2015
#
# Ordinaria
#
# 13/2015
#
# Ordinaria
#
# 2/2015
#
# Ordinaria
#
# 1/2015
#
# Ordinaria
#
# 7/2015
#
# Ordinaria
#
# 2/2015
#
# Ordinaria
#
# 5/2015
#
# Ordinaria
#
# 1/2015
#
# Ordinaria
#
# 3/2015
#
# Ordinaria
#
# 4/2015
#
# Ordinaria
#
# 15/2015
#
# Ordinaria
#
# 7/2015
#
# Ordinaria
#
# 6/2015
#
# Ordinaria
#
# 5/2015
#
# Ordinaria
#
# 4/2015
#
# Ordinaria
#
# 6/2015
#
# Ordinaria
#
# 62/2015
#
# Ordinaria
#
# 3/2015
#
# Ordinaria
#
# 9/2015
#
# Ordinaria
#
# 16/2015
#
# Ordinaria
#
# 3/2015
#
# Ordinaria
#
# 114/2015
#
# Ordinaria
#
# 3/2015
#
# Ordinaria
#
# 11/2015
#
# Ordinaria
#
# 12/2015
#
# Ordinaria
#
# 3/2015
#
# Ordinaria
#
# 2/2015
#
# Ordinaria
#
# 2/2015
#
# Urgente
#
# 101/2015
#
# Urgente
#
# 13/2015
#
# Ordinaria
#
# 59/2015
#
# Ordinaria
#
# 17/2015
#
# Urgente
#
# 113/2015
#
# OrdinariaTipo de contrato:
#
# 7/2015
#
# Ordinaria
#
# 6/2015
#
# Ordinaria
#
# 14/2015
#
# Ordinaria
#
# 143/2015
#
# Ordinaria
#
# 18/2015
#
# Ordinaria
#
# 10/2015
#
# Ordinaria
#
# 19/2015
#
# Ordinaria
#
# 147/2015
#
# Ordinaria
#
# 21/2015
#
# Urgente
#
# 43/2015
#
# Ordinaria
#
# 20/2015
#
# Ordinaria
#
# 104/2015
#
# Ordinaria

# %%
# Extrae los datos de una página de los contratos modificados guardada en una lista de Strings

"""
Num. Expediente
Objeto del Contrato
Tipo de Contrato
Fecha Aprobación
Fecha Inicio
Importe
Causa/Justificación
"""

def extractDataModificados(myList, pages):
  print("Aqui se extraerían los datos de la página " + str(pages))
  cont = 0
  for line in myList:
      print("Line{}: {}".format(cont, line.strip()))
      cont += 1

# %%
# Extrae los datos de una página de los contratos prorrogados guardada en una lista de Strings

"""
Num. Expediente
Objeto del Contrato
Tipo de Contrato
Fecha Aprobación
Fecha Fin Prórroga
Importe
Contratista
"""

def extractDataProrrogados(myList, pages):
  print("Aqui se extraerían los datos de la página " + str(pages))
  cont = 0
  for line in myList:
      print("Line{}: {}".format(cont, line.strip()))
      cont += 1

# %%
# Extrae los datos de una página de los contratos renunciados guardada en una lista de Strings

"""
Num. Expediente
Objeto Contrato
Descripción Lotes Contrato
Tipo Contrato
Tipo Tramitación
Procedimiento de Contratación
Presupuesto de Licitación (IVA incluido)
Plazo Ejecución
Fecha Desistimiento
Fecha Renuncia
Fecha Declaración Desierto
"""

def extractDataRenunciados(myList, pages):
  print("Aqui se extraerían los datos de la página " + str(pages))
  cont = 0
  for line in myList:
      print("Line{}: {}".format(cont, line.strip()))
      cont += 1

# %% [markdown]
# Ya podemos ejecutar las siguientes celdas:

# %%
# Extraemos la página que queramos para poder entender el formato
myList1 = []
pages1 = -1
page1 = 1
extractPage(myList1, pages1, page1)

# %%
# Ejecutar todo
extractPages(myList, pages)
